# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
# !pip install cartopy

# %%
fnames = glob("drive/MyDrive/ColabNotebooks/awesome_project_JS/data/*.dat")
data= []
for fname in fnames:
  data.append(pd.read_csv(fname, names = ["latitude", "longitude", "color", "number"]))

data = pd.concat(data[2:])

# %%
data.plot.scatter(x = "longitude", y = "latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
fnames
# Out:
# ['drive/MyDrive/ColabNotebooks/awesome_project_JS/data/Jocelyn79.dat',
#  'drive/MyDrive/ColabNotebooks/awesome_project_JS/data/picassostriggerfish.dat',
#  'drive/MyDrive/ColabNotebooks/awesome_project_JS/data/rbf.dat']
